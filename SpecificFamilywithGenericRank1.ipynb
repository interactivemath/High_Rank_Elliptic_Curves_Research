# %%
for n in range(1, 10):
    E = EllipticCurve([0, 0, 0, 2^3, 2^(2*n)]);
    print(E.rank(only_use_mwrank=False)); # we are using mwrank = false because of the non-trivial sha group
# Out:
# 1
# 1
# 1
# 1
# 2
# 2
# 1
# 1
# 3
